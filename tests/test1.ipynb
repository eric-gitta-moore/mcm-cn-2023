# %%
from mcm_cn2023.utils.convertEMF import *

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.rcParams["font.sans-serif"] = ["Microsoft YaHei"]
plt.rcParams["axes.unicode_minus"] = False  # 解决无法显示符号的问题
x1 = [0, 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1]
x2 = [0, -0.3, -0.6, -0.9, -1.2, -1.5, -1.8, -2.1]
y1 = [
    415.6921938,
    466.091055,
    516.4899161,
    566.8887772,
    617.2876384,
    667.6864995,
    718.0853607,
    768.4842218,
]
y2 = [
    415.6923457,
    451.3236276,
    486.9549095,
    522.5861914,
    558.2174733,
    593.8487552,
    629.4800371,
    665.1113191,
]
y3 = [
    415.6924976,
    415.6924976,
    415.6924976,
    415.6924976,
    415.6924976,
    415.6924976,
    415.6924976,
    415.6924976,
]
y4 = [
    415.6923457,
    380.0610638,
    344.4297819,
    308.7985,
    273.1672181,
    237.5359362,
    201.9046543,
    166.2733723,
]
y5 = [
    415.6921938,
    365.2933327,
    314.8944715,
    264.4956104,
    214.0967492,
    163.6978881,
    113.299027,
    62.90016582,
]
y6 = [
    415.6923457,
    380.0610638,
    344.4297819,
    308.7985,
    273.1672181,
    237.5359362,
    201.9046543,
    166.2733723,
]
y7 = [
    415.6924976,
    415.6924976,
    415.6924976,
    415.6924976,
    415.6924976,
    415.6924976,
    415.6924976,
    415.6924976,
]
y8 = [
    415.6923457,
    451.3236276,
    486.9549095,
    522.5861914,
    558.2174733,
    593.8487552,
    629.4800371,
    665.1113191,
]

plt.plot(x1, y1, label="β=0°")
plt.plot(x1, y2, label="β=45°")
plt.plot(x1, y3, label="β=90°")
plt.plot(x1, y4, label="β=135°")
plt.plot(x2, y5, label="β=180°")
plt.plot(x2, y6, label="β=225°")
plt.plot(x2, y7, label="β=270°")
plt.plot(x2, y8, label="β=315°")
plt.xlabel("测量船距海域中心点处的距离/海里")
plt.ylabel("覆盖宽度")
plt.legend()
plt.tight_layout()
exportEmf('t')
plt.show()
# Out:
# Failed to get connection
# ** (inkscape:110429): CRITICAL **: 11:43:50.596: dbus_g_proxy_new_for_name: assertion 'connection != NULL' failed
#
# ** (inkscape:110429): CRITICAL **: 11:43:50.596: dbus_g_proxy_call: assertion 'DBUS_IS_G_PROXY (proxy)' failed
#
# ** (inkscape:110429): CRITICAL **: 11:43:50.596: dbus_g_connection_register_g_object: assertion 'connection != NULL' failed
