# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel(r'../../assets/附件.xlsx')

# %%
df
# Out:
#               海水深度/m  Unnamed: 1  横向坐标/NM（由西向东）  Unnamed: 3  Unnamed: 4  \
# 0                NaN         NaN           0.00        0.02        0.04
# 1    纵向坐标/NM\n（由南向北）        0.00          24.40       24.12       23.85
# 2                NaN        0.02          24.32       24.04       23.77
# 3                NaN        0.04          24.25       23.97       23.70
# 4                NaN        0.06          24.17       23.89       23.63
# ..               ...         ...            ...         ...         ...
# 247              NaN        4.92          82.18       82.21       82.23
# 248              NaN        4.94          82.73       82.76       82.79
# 249              NaN        4.96          83.29       83.31       83.34
# 250              NaN        4.98          83.84       83.87       83.90
# 251              NaN        5.00          84.40       84.43       84.46
#
#      Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# ...
